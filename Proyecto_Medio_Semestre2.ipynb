# %% [markdown]
# <a href="https://colab.research.google.com/github/ReginaFierro2000/Visualizacion/blob/main/Proyecto_Medio_Semestre2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyecto de Medio Semestre.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Para el proyecto de Medio Semestre, vamos a trabajar con el dataset contenido en la siguiente pagina:
#
# https://www.kaggle.com/datasets/dipam7/student-grade-prediction
#
# Tu primer tarea sera descargar el archivo (viene en una carpeta comprimida .zip). Una vez descargado (y si estás en Google Colab), haz clic en el dibujo de la carpeta que aparece en la barra de la izquierda, para cargar el archivo.
# SI estás trabajando con Jupyter Notebook, sólo será necesario que especifiques el _path_ correcto hacia tu archivo.
#
# Ya que este cargado, prueba a correr la siguiente celda para leer los datos (adáptala de ser necesario).

# %%
df = pd.read_csv("/content/student-mat.csv")
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Objetivo del Proyecto
#
# Par este proyecto de Medio Semestre vamos a realizar, de manera **individual** un **Análisis Exploratorio de Datos**.
#
# (Por si tienes duda de qué es esto: recordarás que, después de entender lo mejor posible el problema a resolver, el segundo paso en el proceso del Científico de Datos es conocer muy bien los datos que tiene a la mano; para eso, se realiza un AED, o *EDA*, por sus siglas en inglés).
#
# Un repaso de qué se puede hacer está en la siguiente página: https://www.kaggle.com/general/329404
#
# ## El problema a resolver.
#
# Como puedes observar en la página del proyecto, en el primer link de este documento, la idea es analizar los factores que contribuyen de manera más potente en la calificación final de los estudiantes. El dataset Tiene 30 variables con características de los estudiantes y tres calificaciones, `G1`, `G2` y la calificación final, `G3`. Como son estudiantes de Portugal, las calificaciones tienen un valor máximo de 20 puntos.
#
# En esta ocasión, **NO** vamos a llegar al modelado. No contará para su calificación del proyecto. Vamos a trabajar en un paso anterior, que es conocer bien los datos con los que estoy trabajando.
#
# ## ¿Qué se va a calificar?
#
# El proyecto vale 30% de la calificacion final.
#
# * Que respondas a 10 preguntas que tú mismo te hagas sobre los datos.
#
# Para ello, introduce una celda de texto y explícame qué pregunta tienes sobre los datos y que vas a tratar responder. Por ejemplo: ¿Qué calificaciones fueron las más comúnes?
#
# * La gráfica que pudiera ayudarte a responder esa pregunta.
#
# * Una pequeña conclusión.
#
# Esta puede incluir la respuesta a la pregunta que te hiciste, si es que la pudiste resolver con tu código, o si tu respuesta es inconclusa, una hipótesis que explique qué está pasando.
#
# ### Deberás incluir:
#
# * Al menos tres lineas de código con funciones que NO vimos en clase.
# * Al menos cuatro tipos distintos de gráficos.
# * Elementos que hagan más claro tu gráfico (títulos en el gráfico, en los ejes de ser requeridos, que tus ejes comiencen desde 0, colores, leyendas, etc.)
# * Conclusiones apropidas - tu gráfico realmente concuerda con lo explicado en la conclusión.
#
# Cada uno de los elementos que te falten te restarán 2/30 puntos.
#
# ### Posibles puntos extra si:
#
# * Generas gráficos muy estéticos.
# * Traduces muy bien los problemas de la vida real y los conviertes a problemas técnicos, sin perder de vista el problema que estamos tratando de resolver. Asegurate de que estes investigando asuntos relevantes (no seas taaaan especifico, ni tan general).
#
# Fecha de Entrega: domingo 12 de marzo, 11:59 pm.

# %% [markdown]
# ### Ejemplo:
#
# 0. ¿La mayoría de los estudiantes obtuvo una calificación final aprobatoria (10 o más puntos)?

# %%
plt.hist(df["G3"], bins=20)
plt.title("Distribucion de la calificación final.")
plt.xlabel("Calificación Final")
plt.ylabel("Frecuencia")
plt.axvline(x = 10, color = 'r', linestyle = '--')
plt.show()

# %% [markdown]
# Sí. La mayoría de los estudiantes en mi *dataset* obtuvo 10 o más puntos. A pesar de ello, hay un número importante de estudiantes que obtuvo 0 como calificación final.
#
# ¡Tu turno!

# %% [markdown]
# 1. ¿Cuál es el maximo y minimo de estudiantes de mujeres y hombre que estudian matemáticas o portugues?

# %%
#from locale import D_T_FMT
gen_cnt = df['G2'].value_counts()
order = gen_cnt.index
npkmn = gen_cnt.values.sum()
sns.countplot(data=df, y='G2', color='blue')

npkmn = gen_cnt.values.sum()
for i, contador in enumerate(gen_cnt):
   pcnt = '{:0.1f}%'.format(100*contador/npkmn)
   plt.text(contador-20, i, pcnt, va ='center')

#for i in range (len(gen_cnt)):
#   cnt = gen_cnt[i+1]
#   pcnt = '{:0.1f}%'.format(100*cnt/npkmn)
#   plt.text(cnt-20, i, pcnt, va ='center')

# depict illustration
#plt.figure(figsize=(8,25))
#colors_list = ['Red','Orange'] #, 'Blue', 'Purple', 'pink','yellow','green']
#graph = plt.bar(df.sex,df.G3, color = colors_list)
#plt.title('Percentage of runs scored by MS Dhoni across all formats')
 

k = df.groupby("sex")[["G2"]].mean().reset_index()
plt.barh(k["sex"], k["G2"], color = "green")
plt.show()

#npkmn = df.values.sum()
#for i, (valor, contador) in enumerate(ordered):
#   pcnt = '{:0.1f}%'.format(100*contador/npkmn)
#   plt.text(contador-20, i, pcnt, va ='center')

# %%
df["age"].min()
# Out:
# 15

# %%
df["age"].max()
# Out:
# 22

# %% [markdown]
# En la primera gráfica se puede observar que hay mayor cantidad de mujeres de mayor edad con 22 años la edad máxima y en la segunda gráfica podemos observar que la mínima de edad es de 15 años tanto de hombres como de mujeres.

# %% [markdown]
# 3. Tiene que ver el calificacioón final 'G3' con el numero de ausencias?

# %%
#j = df.loc[df['G3'] == 0] & df.loc[df[['absences'][0:38]]]
#g = df.loc[df['absences'][0:38]] #
m = df['traveltime'] & (df['studytime'])
#f = df[]] & (df['studytime'])
j = df[(df['G3']==0) & (df['absences'][0:38])] 

plt.bar(m["sex"])#, j["absences"], color = "purple")
#plt.bar(f["school"])#, j["absences"], color = "yellow")

plt.title("La edad mínima de los estudiantes por sexualidad")
plt.show()
#print(g)
#print(df[(df['G3']==0) & (df['absences'][0:38])])
#pd.merge(j, g, on="absences", how="inner")
#https://www.google.com/search?q=juntar+dos+columnas+para+una+nueva+columna+con+integer+en+dataframe+python&client=firefox-b-d&sxsrf=AJOqlzVJPQOCweKv-hACSV1cQ1ZVNXgrjw%3A1678388083739&ei=cysKZPzeLOq4kPIPwIS-6Ac&ved=0ahUKEwi85Jrsws_9AhVqHEQIHUCCD30Q4dUDCA4&uact=5&oq=juntar+dos+columnas+para+una+nueva+columna+con+integer+en+dataframe+python&gs_lcp=Cgxnd3Mtd2l6LXNlcnAQAzoKCAAQRxDWBBCwAzoECCEQCkoECEEYAFCHD1jrLWD2NWgBcAF4A4ABswKIAZIQkgEHMC44LjIuMpgBAKABAcgBCMABAQ&sclient=gws-wiz-serp
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-a5d8279179e1> in <module>
#       5 j = df[(df['G3']==0) & (df['absences'][0:38])]
#       6
# ----> 7 plt.bar(m["sex"])#, j["absences"], color = "purple")
#       8 #plt.bar(f["school"])#, j["absences"], color = "yellow")
#       9
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ...

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
m = df.groupby('sex').get_group('M')
f = df.groupby('sex').get_group('F')

#j = df.groupby("sex")[["G3"]].mean().reset_index()
plt.barh(m["sex"], m["absences"], color = "blue") # hombres
plt.barh(f["sex"], f["absences"], color = "pink") # mujeres
plt.title("Ausencias entre mujeres y hombres")
plt.show()

# %% [markdown]
# 2. ¿Cómo estan la salud de los estudiantes?

# %%
# Grado 1 de salud de los estudiantes 
h1 = df.loc[df['health'] == 1]
print(h1)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 20      GP   M   15       U     GT3       T     4     3   teacher     other
# 27      GP   M   15       U     GT3       T     4     2    health  services
# 43      GP   M   15       U     GT3       T     2     2  services  services
# 54      GP   F   15       U     LE3       A     3     3     other     other
# 56      GP   F   15       U     GT3       A     4     3  services  services
# 62      GP   F   16       U     LE3       T     1     2     other  services
# 65      GP   F   16       U     LE3       T     4     3   teacher  services
# 76      GP   M   15       U     GT3       T     4     0   teacher     other
# 87      GP   F   15       U     GT3       T     4     2     other     other
# ...

# %%
# Grado 2 de salud de los estudiantes 
h2 = df.loc[df['health'] == 2]
print(h2)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# 15      GP   F   16       U     GT3       T     4     4    health     other
# 16      GP   F   16       U     GT3       T     4     4  services  services
# 33      GP   M   15       U     LE3       T     3     3     other     other
# 39      GP   F   15       R     GT3       T     2     2   at_home     other
# 47      GP   M   16       U     GT3       T     4     3    health  services
# 55      GP   F   16       U     GT3       A     2     1     other     other
# 64      GP   F   15       U     LE3       T     4     3  services  services
# 86      GP   F   16       U     LE3       T     2     2   at_home     other
# 92      GP   F   16       U     LE3       T     3     1     other     other
# 103     GP   F   15       U     GT3       T     3     2  services     other
# ...

# %%
# Grado 3 de salud de los estudiantes 
h3 = df.loc[df['health'] == 3]
print(h3)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1  at_home     other
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 6       GP   M   16       U     LE3       T     2     2    other     other
# 13      GP   M   15       U     GT3       T     4     3  teacher     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 372     MS   F   17       U     GT3       T     2     2    other   at_home
# 376     MS   F   20       U     GT3       T     4     2   health     other
# 382     MS   M   17       U     GT3       T     2     3    other  services
# 384     MS   M   18       R     GT3       T     4     2    other     other
# 392     MS   M   21       R     GT3       T     1     1    other     other
#
# ...

# %%
# Grado 4 de salud de los estudiantes 
h4 = df.loc[df['health'] == 4]
print(h4)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 11      GP   F   15       U     GT3       T     2     1  services     other
# 17      GP   F   16       U     GT3       T     3     3     other     other
# 36      GP   M   15       U     LE3       T     4     3   teacher  services
# 50      GP   F   16       U     LE3       T     2     2  services  services
# 60      GP   F   16       R     GT3       T     4     4    health   teacher
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 359     MS   F   18       U     LE3       T     1     1   at_home  services
# 368     MS   F   18       U     GT3       T     2     3   at_home  services
# 375     MS   F   18       R     GT3       T     1     1     other     other
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# 390     MS   M   20       U     LE3       A     2     2  services  services
#
# ...

# %%
# Grado 5 de salud de los estudiantes 
h5 = df.loc[df['health'] == 5]
print(h5)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 12      GP   M   15       U     LE3       T     4     4    health  services
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 386     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
# !pip install pywaffle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 17.0 MB/s eta 0:00:00
# ...

# %%
from pywaffle import Waffle

# %%
salud = {"Excelente 5": 146, "Muy bueno 4" : 66, "Bueno 3": 91, "Regular 2": 45, "Malo 1": 47}

plt.figure(
    FigureClass = Waffle,
    rows = 18,
    values = salud,
    colors=('#ff7f0e', '#2ca02c', '#d62728', '#9467bd','blue'),
    legend={"loc":"upper center"},
    icons = 'pen',icon_size=12)

plt.title("Total de propinas por día")
plt.show()
# Out:
# <Waffle size 432x288 with 1 Axes>

# %% [markdown]
# Se puede observar que hay mayor cantidad de estudiantes con bueno salud presentandose con grado excelente de 146, muy bueno de 66 y el límite que es el grado bueno con 91; pero tambien hay estudiantes que descuidan su salud con grado regular de 45 y grado de mala salud de 47 estudiantes.

# %%
#sns.pairplot(df)

# %%
#sns.pairplot(df, hue='G3')

# %% [markdown]
# Ausencias escolares por edades

# %%
plt.scatter(df["age"],	df["absences"])
plt.title("Ausencias escolares por edades")
plt.xlabel("Edad")
plt.ylabel("Ausencias")
plt.show()

# %%
plt.bar(df['school'], df['absences'], label='Ausencias por escuela', color = 'aqua')
plt.xlabel('Escuelas')
plt.ylabel('Ausencias')
plt.title('Ausencias por escuela')
plt.grid(True)
plt.legend()

# %%
print(df.groupby('sex').agg(np.mean))
# Out:
#            age      Medu      Fedu  traveltime  studytime  failures    famrel  \
# sex
# F    16.730769  2.668269  2.485577    1.408654   2.278846  0.302885  3.894231
# M    16.657754  2.839572  2.561497    1.491979   1.764706  0.368984  4.000000
#
#      freetime     goout      Dalc      Walc    health  absences         G1  \
# sex
# F    3.009615  3.028846  1.254808  1.956731  3.365385  6.216346  10.620192
# M    3.486631  3.197861  1.732620  2.663102  3.764706  5.144385  11.229947
#
#             G2         G3
# sex
# F    10.389423   9.966346
# M    11.074866  10.914439

# %%
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(8, 4))
sns.scatterplot(x="age", y="G3", hue="internet", data=df, ax=axes[0])
axes[0].set_title('Calificación final')
sns.scatterplot(x="age", y="G2", hue="internet", data=df, ax=axes[1])
axes[1].set_title('Calificación segundo parcial')
# Out:
# Text(0.5, 1.0, 'Calificación segundo parcial')

# %%
plt.figure(figsize=(9,8))
plt.title('fghjk')
#plt.style.use("dark_background") 
sns.scatterplot(x='age',y='G3',marker='+',hue='activities',style='activities',palette='plasma',data=df) #magma, plasma
# Out:
# <AxesSubplot:title={'center':'fghjk'}, xlabel='age', ylabel='G3'>

# %%
r = np.random.RandomState(0)
x = df["age"].values
y = df["G3"].values
colors = r.rand(395)
sizes = 1000 * r.rand(395)

plt.subplots(sharey=True, figsize=(15, 15))
plt.scatter(x,y,c=colors,s=sizes,cmap='viridis')
plt.annotate("No", (15, 7.5),size=17, color = 'Black',
             ha='center', va="center")
plt.annotate("Yes", (16,20),size=13, color = 'w',
             ha='center', va="center")
plt.colorbar();
#https://towardsdatascience.com/texts-fonts-and-annotations-with-pythons-matplotlib-dfbdea19fc57

# %%
sns.displot(df, x="Dalc", y= "age", kind="hist")
plt.title("workday alcohol consumption age")
plt.show()

sns.displot(data=df, x="Dalc", hue="freetime", kind="kde")
sns.displot(data=df, x="Dalc", hue="age", kind="kde")
#df.set_axis_labels("Edad", "Grado de alcohol(1-5)")
#df.set_titles("Alcoholismo en los estudiantes por edad")
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
#sns.displot(data=df, x="Dalc", hue="freetime", kind="kde")

g = sns.displot(
    data=df, y="Dalc", hue="freetime", col="freetime",
    kind="kde", height=4, aspect=.7,
)
g.set_axis_labels("Grado de alcohol(1-5)", "Tiempo libre")
g.set_titles(" grado")

sns.displot(
    data=df, y="Dalc", hue="freetime", col="freetime",
    kind="ecdf", height=4, aspect=.7,
)

# %%
sns.set(style='dark',)
res = sns.kdeplot(df['goout'],df['absences'],shade=True,cmap="Oranges") 
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.kdeplot(
    data=df, x="goout", y="absences", hue="schoolsup",
    levels=5, thresh=.2,
)
# Out:
# <AxesSubplot:xlabel='goout', ylabel='absences'>

# %%
sns.kdeplot(
    data=df, x="Walc", y="age", hue="school",
    levels=5, thresh=.2,
)
# Out:
# <AxesSubplot:xlabel='Walc', ylabel='age'>

# %%
sns.kdeplot(
    data=df, x="age", y="absences", hue="reason",
    levels=5, thresh=.2,
)
plt.style.use("dark_background")
# Out:
# <AxesSubplot:xlabel='age', ylabel='absences'>

# %%
sns.catplot(
    data=df, x="age", y="absences", col="sex",
    kind="bar", height=4, aspect=.6,
)
plt.style.use("dark_background")

# %%
sns.catplot(
    data=df, x="reason", y="G3", col="sex",
    kind="bar", height=4, aspect=1,
)
plt.style.use("dark_background")

# %%
sns.catplot(
    data=df, x="address", y="age", col="sex",
    kind="bar", height=4, aspect=1,
)
plt.style.use("dark_background")
