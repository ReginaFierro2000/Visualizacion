# %% [markdown]
# <a href="https://colab.research.google.com/github/ReginaFierro2000/Visualizacion/blob/main/Ejercicio_4.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Ejercicio 4
# ## Variables Numericas

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### 1. Crea un Histograma para la variable *petal_length*. Trata de escoger un buen numero de bins y observa el patron. Observa: ¿cuantos maximos locales existen?

# %%
plt.hist(iris.petal_length, bins=10, color = "orange")
plt.title("Distribucion de la longitud del pétalo de la flor iris")
plt.show()
# ¿cuantos maximos locales existen?
# Se pueden observar 9 máximos locales con un número de bins de 10.

# %% [markdown]
# ### 2. Usando `seaborn`, crea un KDE plot para la misma variable. Escoge un buen bandwidth.

# %%
sns.kdeplot(iris.petal_length, bw_adjust=0.20, color = "black")
plt.title("Distribucion de la longitud del pétalo de la flor iris")
plt.show()

# %% [markdown]
# Parecieran haber dos, o quiza, tres maximos. ¿Sera que cada uno de ellos corresponde al valor mas comun para cada uno de las distintas `species`?
#
# ### 3. Usa `sns.displot` para crear un histograma o un KDE plot. Investiga como funciona el parametro *hue* y usalo para probar lo anterior.

# %%
sns.displot(iris, x="petal_length", kind="hist", hue = "petal_length")
plt.title("Distribucion de la longitud del pétalo de la flor iris")
plt.show()

sns.histplot(iris["petal_length"], kde=True, color = "blue")
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %% [markdown]
# ### 4. Crea un _scatterplot_ entre las variables *petal_length* y *sepal_length*. Asegurate que los ejes X y Y empiecen en 0.

# %%
#colors = dict(zip(['2', '1', '0'], sns.color_palette('tab10_r', 3)))
plt.scatter(iris["petal_length"],	iris["sepal_length"])
plt.ylim(0, 10)
plt.xlim(0,10)
plt.title("longitud del pétalo vs longitud del sépalo")
plt.xlabel("longitud del pétalo")
plt.ylabel("longitud del sépalo")
plt.show()

# Es mejor empezar desde el valor (4, 8.5) del eje de las y y del eje de las x es mejor el valor (0,8)
plt.scatter(iris["petal_length"],	iris["sepal_length"], color = "red")
plt.ylim(4, 8.5)
plt.xlim(0,8)
plt.title("longitud del pétalo vs longitud del sépalo")
plt.xlabel("longitud del pétalo")
plt.ylabel("longitud del sépalo")
plt.show()

# %% [markdown]
# ### 5. Usa seaborn o matplotlib para crear un grafico de dispersion con las variables *petal_length* y *sepal_length*. Ahora colorea los puntos segun *species* y asegurate de incluir una leyenda.

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x="petal_length", 
                y="sepal_length", 
                hue="species",
                data=iris)
plt.xlabel("petal_length")
plt.ylabel("sepal_length")
# Out:
# Text(0, 0.5, 'sepal_length')

# %% [markdown]
# ¿Notaste como una buena grafica te ayuda a ver las caracteristicas que distinguen a cada especie, sin tener que hacer un modelo?

# %%
# si, colocando correctamento los parámetros necesarios para saber interpretar una buena gráfica nos permite distinguir, en este caso, como se ven distribuyendo las especies;
# con esta función es más precisa y una mejor visualización para los datos.
